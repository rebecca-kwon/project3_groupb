# %%
import pandas as pd

# %%
michelin = pd.read_csv('michelin_hotels_atlantean.csv')
michelin_df = pd.DataFrame(michelin)
michelin_df.head(40)
# Out:
#     Unnamed: 0                               name michelin_award  \
# 0            7                       't Raedthuys       ONE_STAR
# 1           13       1131 - Abbaye de la Bussière       ONE_STAR
# 2           21                               21.9       ONE_STAR
# 3           24                               360°       ONE_STAR
# 4           26                        7132 Silver      TWO_STARS
# 5           59                        Acqua Pazza       ONE_STAR
# 6           68                              Adler       ONE_STAR
# 7           69                            Admiral       ONE_STAR
# 8           77                           Ahlmanns       ONE_STAR
# 9           80                       Aigue Marine       ONE_STAR
# 10          98                           Al Metrò       ONE_STAR
# 11         116  Alexander Herrmann by Tobias Bätz      TWO_STARS
# 12         121                        All'Enoteca       ONE_STAR
# ...

# %%
atlantean = michelin_df[michelin_df["Hotel_Name"].str.contains("Atlanta")==False]
atlantean.head(40)
# Out:
#     Unnamed: 0                               name michelin_award  \
# 0            7                       't Raedthuys       ONE_STAR
# 1           13       1131 - Abbaye de la Bussière       ONE_STAR
# 2           21                               21.9       ONE_STAR
# 4           26                        7132 Silver      TWO_STARS
# 6           68                              Adler       ONE_STAR
# 7           69                            Admiral       ONE_STAR
# 9           80                       Aigue Marine       ONE_STAR
# 10          98                           Al Metrò       ONE_STAR
# 11         116  Alexander Herrmann by Tobias Bätz      TWO_STARS
# 12         121                        All'Enoteca       ONE_STAR
# 13         124                             Allium       ONE_STAR
# 14         136                            Alt Wyk       ONE_STAR
# 15         137                          Alte Baiz       ONE_STAR
# ...

# %%
len(atlantean)
# Out:
# 252

# %%
atlantean.to_csv('not_atlantean.csv',index=False)
